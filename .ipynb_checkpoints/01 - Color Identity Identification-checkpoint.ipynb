# %%
import pandas as pd
from PIL import Image
import os
import cv2
df=pd.read_csv('Relevent_Cards.csv', index_col=0)

# %%
cards_with_images=df[df['multiverseid'].notnull()]

# %%
subset=cards_with_images.sample(10000)
train_set=subset[0:6000]
test_set=subset[6001:10001]

# %%
def load_and_crop_image(multiverse_id):
    im=cv2.imread('Cards/'+str(multiverse_id)+'.jpg')
    w, h, channels = im.shape
    return im[30:165, 25:195]
X_train=[]
X_test=[]
for i in train_set.multiverseid:
    X_train=X_train+[load_and_crop_image(int(i))]
for i in test_set.multiverseid:
    X_test=X_test+[load_and_crop_image(int(i))]
import numpy as np
from PIL import Image
X_train=np.array(X_train)
X_test=np.array(X_test)

# %%
y_train=[]
for i in train_set['colorIdentity'].fillna('[]').values:
    cid=[0,0,0,0,0]
    if 'W' in i:
        cid[0]+=1
    if 'U' in i:
        cid[1]+=1
    if 'B' in i:
        cid[2]+=1
    if 'R' in i:
        cid[3]+=1
    if 'G' in i:
        cid[4]+=1
    y_train=y_train+[cid]
y_test=[]
for i in test_set['colorIdentity'].fillna('[]').values:
    cid=[0,0,0,0,0]
    if 'W' in i:
        cid[0]+=1
    if 'U' in i:
        cid[1]+=1
    if 'B' in i:
        cid[2]+=1
    if 'R' in i:
        cid[3]+=1
    if 'G' in i:
        cid[4]+=1
    y_test=y_test+[cid]
y_train=np.array(y_train)
y_test=np.array(y_test)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
plt.imshow(X_test[0])

# %%
X_train = X_train.reshape(X_train.shape[0], 135, 170, 3)
X_test = X_test.reshape(X_test.shape[0], 135, 170, 3)

# %%
print X_train.shape
# Out:
# (6000, 135, 170, 3)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(135,170, 3)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dropout(0.10))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.20))
model.add(Dense(5, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=32, epochs=10, verbose=1)
# Out:
# Epoch 1/25
# 6000/6000 [==============================] - 124s - loss: 1.6186 - acc: 0.3045
# Epoch 2/25
# 6000/6000 [==============================] - 116s - loss: 1.2286 - acc: 0.5713
# Epoch 3/25
# 6000/6000 [==============================] - 121s - loss: 0.9204 - acc: 0.6958
# Epoch 4/25
# 6000/6000 [==============================] - 118s - loss: 0.8417 - acc: 0.7305
# Epoch 5/25
# 6000/6000 [==============================] - 116s - loss: 0.7522 - acc: 0.7640
# Epoch 6/25
# 6000/6000 [==============================] - 116s - loss: 0.6496 - acc: 0.7845
# Epoch 7/25
# 6000/6000 [==============================] - 116s - loss: 0.5635 - acc: 0.8210
# Epoch 8/25
# 6000/6000 [==============================] - 116s - loss: 0.4947 - acc: 0.8425
# Epoch 9/25
# 6000/6000 [==============================] - 116s - loss: 0.4271 - acc: 0.8560
# Epoch 10/25
# 6000/6000 [==============================] - 116s - loss: 0.4012 - acc: 0.8673
# Epoch 11/25
# 6000/6000 [==============================] - 116s - loss: 0.3745 - acc: 0.8757
# Epoch 12/25
# 6000/6000 [==============================] - 116s - loss: 0.3557 - acc: 0.8777
# Epoch 13/25
# 6000/6000 [==============================] - 116s - loss: 0.3334 - acc: 0.8863
# Epoch 14/25
# 6000/6000 [==============================] - 116s - loss: 0.3221 - acc: 0.8842
# Epoch 15/25
# 6000/6000 [==============================] - 116s - loss: 0.3183 - acc: 0.8847
# Epoch 16/25
# 6000/6000 [==============================] - 116s - loss: 0.2926 - acc: 0.8863
# Epoch 17/25
# 6000/6000 [==============================] - 116s - loss: 0.2945 - acc: 0.8888
# Epoch 18/25
# 6000/6000 [==============================] - 116s - loss: 0.2897 - acc: 0.8875
# Epoch 19/25
# 6000/6000 [==============================] - 143s - loss: 0.2956 - acc: 0.8763
# Epoch 20/25
# 6000/6000 [==============================] - 116s - loss: 0.2915 - acc: 0.8848
# Epoch 21/25
# 6000/6000 [==============================] - 116s - loss: 0.2825 - acc: 0.8805
# Epoch 22/25
# 6000/6000 [==============================] - 116s - loss: 0.2758 - acc: 0.8787
# Epoch 23/25
# 6000/6000 [==============================] - 116s - loss: 0.2788 - acc: 0.8863
# Epoch 24/25
# 6000/6000 [==============================] - 116s - loss: 0.2881 - acc: 0.8802
# Epoch 25/25
# 6000/6000 [==============================] - 116s - loss: 0.2842 - acc: 0.8825

# %%
score = model.evaluate(X_test, y_test, verbose=0)

# %%
print score
# Out:
# [1.5109035397923329, 0.71942985730041231]

# %%
model.predict(X_test)
# Out:
# array([[  9.76228356e-01,   4.15713259e-07,   8.74078646e-03,
#           4.07904293e-03,   1.09513905e-02],
#        [  1.41636241e-08,   5.57046292e-07,   9.99999166e-01,
#           1.49711653e-07,   1.27038774e-07],
#        [  4.15907592e-01,   6.91253915e-02,   2.09612861e-01,
#           8.93387944e-02,   2.16015384e-01],
#        ...,
#        [  1.74414497e-02,   4.08539064e-02,   2.76403385e-03,
#           9.32560444e-01,   6.38014823e-03],
#        [  2.29471753e-09,   2.93613328e-11,   1.65074300e-06,
#           3.13807764e-11,   9.99998331e-01],
#        [  6.29799479e-06,   9.99982357e-01,   8.57568466e-06,
#           2.65986819e-06,   9.75265451e-08]], dtype=float32)

# %%
test_set.tail(5)
# Out:
#        multiverseid                  name          artist         colors  \
# 6862       405453.0        Wistful Selkie      Mark Tedin  [Blue, Green]
# 8105       416796.0  Archdemon of Paliano    Evan Shipard        [Black]
# 22908       24640.0               Inflame   Eric Peterson          [Red]
# 12761      366269.0    Serene Remembrance   David Palumbo        [Green]
# 7668         2810.0             Juxtapose  Justin Hampton         [Blue]
#
#       colorIdentity  layout  cmc    rarity                       type  \
# 6862         [U, G]  normal  3.0  Uncommon  Creature — Merfolk Wizard
# 8105            [B]  normal  4.0      Rare           Creature — Demon
# 22908           [R]  normal  1.0    Common                    Instant
# 12761           [G]  normal  1.0  Uncommon                    Sorcery
# 7668            [U]  normal  4.0      Rare                    Sorcery
#
#                 subtypes supertypes power toughness  set
# 6862   [Merfolk, Wizard]        NaN     2         2  C15
# 8105             [Demon]        NaN     5         4  CN2
# 22908                NaN        NaN   NaN       NaN  PCY
# 12761                NaN        NaN   NaN       NaN  GTC
# 7668                 NaN        NaN   NaN       NaN  CHR
